# %%
import numpy as np
import numpy_financial as npf
import pandas as pd
from scipy.stats import weibull_min, uniform
import matplotlib.pyplot as plt
import seaborn as sns
import model_functions as func

# %%
# Indlæs befolkningsdata
befolkning_eu = pd.read_csv("./populationsdata/unpopulation_dataportal_EU.csv")
befolkning_na = pd.read_csv("./populationsdata/unpopulation_dataportal_NA.csv")
befolkning_eu["region"] = "eu"
befolkning_na["region"] = "na"
befolkning = pd.concat([befolkning_eu, befolkning_na])

# %%
# Opsæt simuleringsparametre
simuleringsparametre = {
    'præklinisk_succes_sandsynlighed': 0.8,  # Assuming preclinical to Phase 1 success rate
    'præklinisk_omkostningsinterval': (2e6, 5e6),
    'præklinisk_tidsinterval': (1, 3),
    'fase1_succes_sandsynlighed': 0.8,  # Phase 1 to Phase 2
    'fase1_omkostningsinterval': (1e6, 3e6),
    'fase1_tidsinterval': (0.5, 1.5),
    'fase2_succes_sandsynlighed': 0.7,  # Phase 2 to Phase 3
    'fase2_omkostningsinterval': (5e6, 10e6),
    'fase2_tidsinterval': (1, 2),
    'fase3_succes_sandsynlighed': 0.8,  # Phase 3 to NDA/BLA
    'fase3_omkostningsinterval': (20e6, 50e6),
    'fase3_tidsinterval': (2, 4),
    'godkendelse_succes_sandsynlighed': 0.95,  # NDA/BLA to Approval
    'godkendelse_omkostningsinterval': (2e6, 5e6),
    'godkendelse_tidsinterval': (0.5, 1.5),
    'markedspenetration': func.triangular_distribution(0.3, 0.4, 0.5),  # Capped at 50% as requested
    'pris': func.triangular_distribution(1e6, 2.5e6, 4e6),
    'odd_cost_reduction': uniform(0.25, 0.5).rvs(),
    'prv_value': func.triangular_distribution(50e6, 100e6, 200e6),
    'odd_probability': 0.95,
    'rpdd_probability': 0.90,
    'adoptionsparametre': {
        'us': {
            'maks_adoption': uniform(0.2, 0.3).rvs(),  # Lowered from 0.4-0.5
            'forsinkelse': uniform(2, 4).rvs(),        # Increased from 0.5-2
            'hastighed': uniform(0.3, 0.7).rvs()       # Decreased from 0.7-1.7
        },
        'eu': {
            'maks_adoption': uniform(0.15, 0.25).rvs(),  # Lowered from 0.3-0.4
            'forsinkelse': uniform(3, 5).rvs(),          # Increased from 1-3
            'hastighed': uniform(0.2, 0.5).rvs()         # Decreased from 0.5-1.3
        }
    },
    'produktionsomkostning': func.triangular_distribution(3e5, 5e5, 7e5),
    'kommercialiseringsår': 5,
    'diskonteringsrente': 0.25,  # Updated to 25% as requested
    'risikofaktorer': {
        'præklinisk': [0.9],
        'fase1': [0.8],
        'fase2': [0.7],
        'fase3': [0.6],
        'godkendt': [0.2, 0.15, 0.1, 0.05, 0]
    }
}

# %%
# Kør befolkningsfremskrivning
lowe_syndrom_data = func.lowe_syndrom_fremskrivning(
    befolkning, ['eu', 'na'], prævalens=1/250000, maks_levetid=40, form=2, skala=15
)

# %%
# Kør Monte Carlo-simulation
antal_simuleringer = 10000
resultater, alle_patienter, alle_behandlede_patienter = func.monte_carlo_simulation(antal_simuleringer, lowe_syndrom_data, simuleringsparametre)

# %%
# Analyser og visualiser resultater
df_resultater = pd.DataFrame(resultater)
df_resultater = df_resultater.replace([np.inf, -np.inf], np.nan)
print("Sammenfatning af resultater:")
print(df_resultater.describe().round())
# Out:
# Sammenfatning af resultater:
#        præklinisk_npv   fase1_npv   fase2_npv   fase3_npv  godkendt_npv  \
# count          3351.0      3351.0      3351.0      3351.0        3351.0
# mean       33562902.0  53104199.0  59579663.0  46264953.0   228390409.0
# std          966177.0   1457580.0   2007135.0   6049230.0    16548645.0
# min        29027014.0  46826807.0  51386781.0  30082024.0   170725114.0
# 25%        32952965.0  52083290.0  58169260.0  41198903.0   222901187.0
# 50%        33600143.0  53119433.0  59594145.0  46369288.0   231471600.0
# 75%        34260000.0  54176597.0  60970976.0  51323907.0   239947403.0
# max        36081189.0  56953589.0  65340339.0  59385255.0   253437130.0
#
#        præklinisk_roi  fase1_roi  fase2_roi  fase3_roi  godkendt_roi  ...  \
# count          3351.0     3351.0     3351.0     3351.0        3351.0  ...
# mean          15058.0     6482.0     1999.0      421.0         362.0  ...
# std            4657.0     1585.0      372.0      130.0         105.0  ...
# min            3650.0     2450.0     1078.0      178.0         152.0  ...
# 25%           11565.0     5367.0     1723.0      314.0         276.0  ...
# 50%           14120.0     6265.0     1949.0      400.0         347.0  ...
# 75%           18116.0     7373.0     2252.0      514.0         440.0  ...
# max           27648.0    12109.0     3387.0      798.0         662.0  ...
#
#        totale_omkostninger  total_omsætning   burn_rate  præklinisk_tid  \
# count               3351.0           3351.0      3351.0          3351.0
# mean           160485704.0      600763187.0   6120163.0             2.0
# std              8859363.0        3988475.0   1289681.0             1.0
# min            141262361.0      587796343.0   3118770.0             1.0
# 25%            152988946.0      596803730.0   5121021.0             1.0
# 50%            160369835.0      600921393.0   6025539.0             2.0
# 75%            167935833.0      604781702.0   7007659.0             3.0
# max            178665230.0      610443488.0  11269502.0             3.0
#
#        fase1_tid  fase2_tid  fase3_tid  godkendelse_tid  samlet_tid  \
# count     3351.0     3351.0     3351.0           3351.0      3351.0
# mean         1.0        1.0        3.0              1.0         8.0
# std          0.0        0.0        1.0              0.0         1.0
# min          1.0        1.0        2.0              1.0         6.0
# 25%          1.0        1.0        3.0              1.0         8.0
# 50%          1.0        2.0        3.0              1.0         8.0
# 75%          1.0        2.0        3.0              1.0         9.0
# max          1.0        2.0        4.0              1.0        11.0
#
#         prv_value
# count      3351.0
# mean   62074790.0
# std    21438198.0
# min           0.0
# 25%    69476493.0
# 50%    69476493.0
# 75%    69476493.0
# max    69476493.0
#
# [8 rows x 25 columns]

# %%
# Beregn gennemsnitsværdier for hver fase
gennemsnit_værdier = {
    'Præklinisk NPV': np.nanmean(df_resultater['præklinisk_npv']),
    'Fase 1 NPV': np.nanmean(df_resultater['fase1_npv']),
    'Fase 2 NPV': np.nanmean(df_resultater['fase2_npv']),
    'Fase 3 NPV': np.nanmean(df_resultater['fase3_npv']),
    'Godkendt NPV': np.nanmean(df_resultater['godkendt_npv'])
}
print("\nGennemsnitlige risikojusterede NPV-værdier for hver fase:")
for fase, værdi in gennemsnit_værdier.items():
    print(f"{fase}: {værdi:,.2f} kr")
# Out:
# Gennemsnitlige risikojusterede NPV-værdier for hver fase:
# Præklinisk NPV: 33,562,902.45 kr
# Fase 1 NPV: 53,104,198.51 kr
# Fase 2 NPV: 59,579,662.77 kr
# Fase 3 NPV: 46,264,953.14 kr
# Godkendt NPV: 228,390,409.43 kr

# %%
# Beregn gennemsnitlige ROI-værdier for hver fase
gennemsnit_roi = {
    'Præklinisk ROI': np.mean(df_resultater['præklinisk_roi']),
    'Fase 1 ROI': np.mean(df_resultater['fase1_roi']),
    'Fase 2 ROI': np.mean(df_resultater['fase2_roi']),
    'Fase 3 ROI': np.mean(df_resultater['fase3_roi']),
    'Godkendt ROI': np.mean(df_resultater['godkendt_roi'])
}

print("\nGennemsnitlige ROI-værdier for hver fase:")
for fase, værdi in gennemsnit_roi.items():
    print(f"{fase}: {værdi:.2f}%")
# Out:
# Gennemsnitlige ROI-værdier for hver fase:
# Præklinisk ROI: 15057.58%
# Fase 1 ROI: 6481.89%
# Fase 2 ROI: 1999.38%
# Fase 3 ROI: 420.70%
# Godkendt ROI: 362.41%

# %%
# Beregn gennemsnitlige omkostninger og omsætning
gns_omkostninger = np.mean(df_resultater['totale_omkostninger'])
gns_omsætning = np.mean(df_resultater['total_omsætning'])

print(f"\nGennemsnitlige totale omkostninger: {gns_omkostninger:,.2f} kr")
print(f"Gennemsnitlig total omsætning: {gns_omsætning:,.2f} kr")
# Out:
# Gennemsnitlige totale omkostninger: 160,485,704.47 kr
# Gennemsnitlig total omsætning: 600,763,186.79 kr

# %%
# Beregn gennemsnitlig burn rate
gns_burn_rate = np.mean(df_resultater['burn_rate'])
print(f"\nGennemsnitlig burn rate: {gns_burn_rate:,.2f} kr/år")
# Out:
# Gennemsnitlig burn rate: 6,120,163.37 kr/år

# %%
# Beregn gennemsnitlig udviklingstid
gns_udviklingstid = np.mean(df_resultater['samlet_tid'])
print(f"Gennemsnitlig udviklingstid: {gns_udviklingstid:.2f} år")
# Out:
# Gennemsnitlig udviklingstid: 8.50 år

# %%
# Scenarieanalyse
print("\nScenarie analyse:")
scenarier = ['Optimistisk', 'Base case', 'Pessimistisk']
percentiler = [75, 50, 25]

for scenarie, percentil in zip(scenarier, percentiler):
    npv = np.percentile(df_resultater['godkendt_npv'], percentil)
    roi = np.percentile(df_resultater['godkendt_roi'], percentil)
    print(f"{scenarie} scenarie:")
    print(f"  NPV: {npv:,.2f} kr")
    print(f"  ROI: {roi:.2f}%")
# Out:
# Scenarie analyse:
# Optimistisk scenarie:
#   NPV: 239,947,403.40 kr
#   ROI: 439.90%
# Base case scenarie:
#   NPV: 231,471,599.67 kr
#   ROI: 346.70%
# Pessimistisk scenarie:
#   NPV: 222,901,187.02 kr
#   ROI: 276.14%

# %%
# Visualiseringer
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_resultater[['præklinisk_npv', 'fase1_npv', 'fase2_npv', 'fase3_npv', 'godkendt_npv']])
plt.title('Risikojusteret NPV på forskellige stadier')
plt.ylabel('NPV (kr)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=df_resultater[['præklinisk_roi', 'fase1_roi', 'fase2_roi', 'fase3_roi', 'godkendt_roi']])
plt.title('ROI på forskellige stadier')
plt.ylabel('ROI (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data=df_resultater, x='godkendt_npv', kde=True)
plt.title('Fordeling af godkendt risikojusteret NPV')
plt.xlabel('NPV (kr)')
plt.tight_layout()
plt.show()

# %%
# Beregn succesrate for hele udviklingsprocessen
succesfulde_simuleringer = len(df_resultater)
samlet_succesrate = succesfulde_simuleringer / antal_simuleringer

print(f"\nSamlet succesrate for udviklingsprocessen: {samlet_succesrate:.2%}")
# Out:
# Samlet succesrate for udviklingsprocessen: 33.51%

# %%
# Beregn forventet værdi af projektet
forventet_værdi = np.mean(df_resultater['godkendt_npv']) * samlet_succesrate
print(f"\nForventet værdi af projektet: {forventet_værdi:,.2f} kr")
# Out:
# Forventet værdi af projektet: 76,533,626.20 kr

# %%
# Beregn break-even tid
kumulativ_pengestrøm = np.cumsum([-gns_omkostninger] + [gns_omsætning / simuleringsparametre['kommercialiseringsår']] * simuleringsparametre['kommercialiseringsår'])
break_even_tid = np.argmax(kumulativ_pengestrøm >= 0) + gns_udviklingstid
print(f"Forventet break-even tid: {break_even_tid:.2f} år efter projektstart")
# Out:
# Forventet break-even tid: 10.50 år efter projektstart

# %%
# Investeringsbehov for hver fase
print("\nEstimeret investeringsbehov for hver fase:")
print(f"Præklinisk: {np.mean(df_resultater['præklinisk_npv']):,.2f} kr")
print(f"Fase 1: {np.mean(df_resultater['fase1_npv'] - df_resultater['præklinisk_npv']):,.2f} kr")
print(f"Fase 2: {np.mean(df_resultater['fase2_npv'] - df_resultater['fase1_npv']):,.2f} kr")
print(f"Fase 3: {np.mean(df_resultater['fase3_npv'] - df_resultater['fase2_npv']):,.2f} kr")
print(f"Godkendelse: {np.mean(df_resultater['godkendt_npv'] - df_resultater['fase3_npv']):,.2f} kr")
# Out:
# Estimeret investeringsbehov for hver fase:
# Præklinisk: 33,562,902.45 kr
# Fase 1: 19,541,296.06 kr
# Fase 2: 6,475,464.26 kr
# Fase 3: -13,314,709.63 kr
# Godkendelse: 182,125,456.29 kr

# %%
odd_success_rate = df_resultater['odd_obtained'].mean()
rpdd_success_rate = df_resultater['rpdd_obtained'].mean()

print(f"Orphan Drug Designation obtained in {odd_success_rate:.2%} of simulations")
print(f"Rare Pediatric Disease Designation obtained in {rpdd_success_rate:.2%} of simulations")

prv_values = df_resultater[df_resultater['prv_value'] > 0]['prv_value']
if not prv_values.empty:
    avg_prv_value = np.nanmean(prv_values)
    print(f"Average PRV value when obtained: {avg_prv_value:,.2f} kr")
else:
    print("No PRV values were obtained in the simulations")
# Out:
# Orphan Drug Designation obtained in 95.26% of simulations
# Rare Pediatric Disease Designation obtained in 89.35% of simulations
# Average PRV value when obtained: 69,476,493.23 kr

# %%
# Beregn gennemsnit af patient data
gennemsnit_patienter = np.mean(alle_patienter, axis=0)
gennemsnit_behandlede = np.mean(alle_behandlede_patienter, axis=0)

# Plot patient adoption
func.plot_patient_adoption(gennemsnit_patienter, gennemsnit_behandlede, simuleringsparametre['adoptionsparametre'], simuleringsparametre['kommercialiseringsår'])

# %%
# Run the analysis
impacts = func.calculate_parameter_impacts(resultater,simuleringsparametre,lowe_syndrom_data)
plot_impact_chart(impacts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Run the analysis
# ----> 2 impacts = func.calculate_parameter_impacts(resultater,simuleringsparametre)
#       3 plot_impact_chart(impacts)
#
# File ~/Desktop/Lowe Syndrome Collaborative/Finansiel model/model_functions.py:517, in calculate_parameter_impacts(resultater, base_params, variation)
#     515 for param in base_params:
#     516     if param not in ['risikofaktorer', 'kommercialiseringsår']:  # Skip complex parameters
# --> 517         new_npv = run_simulation_with_varied_param(base_params, param, variation)
#     518         impacts[param] = new_npv - base_npv
#     520 return impacts
#
# File ~/Desktop/Lowe Syndrome Collaborative/Finansiel model/model_functions.py:508, in run_simulation_with_varied_param(base_params, param_name, variation)
#     505 new_params[param_name] = vary_param(base_params[param_name], variation)
#     507 # Run simulation with new params and return NPV
# --> 508 results, _, _ = monte_carlo_simulation(1000, lowe_syndrom_data, new_params)
#     509 return np.mean([r['godkendt_npv'] for r in results])
#
# NameError: name 'lowe_syndrom_data' is not defined

# %%
def generate_cash_flow(simulation_result):
    development_years = int(simulation_result['samlet_tid'])
    commercialization_years = 20
    total_years = development_years + commercialization_years
    
    cash_flow = np.zeros(total_years)
    cash_flow[:development_years] = -simulation_result['totale_omkostninger'] / development_years
    cash_flow[development_years:] = simulation_result['total_omsætning'] * 0.8 / commercialization_years
    
    return pd.Series(cash_flow)

def plot_cash_flow_projections(results, sample_size=100):
    sampled_results = results if len(results) <= sample_size else np.random.choice(results, sample_size, replace=False)
    cash_flows = pd.DataFrame([generate_cash_flow(r) for r in sampled_results])
    
    mean_cash_flow = cash_flows.mean()
    std_cash_flow = cash_flows.std()
    
    years = range(len(mean_cash_flow))
    plt.figure(figsize=(12, 6))
    plt.plot(years, mean_cash_flow, label='Mean Cash Flow')
    plt.fill_between(years, mean_cash_flow - std_cash_flow, mean_cash_flow + std_cash_flow, alpha=0.2)
    plt.title('Cash Flow Projections')
    plt.xlabel('Years')
    plt.ylabel('Cash Flow ($)')
    plt.axhline(y=0, color='r', linestyle='--')
    plt.legend()
    plt.show()

def plot_npv_distribution(results):
    npvs = [r['godkendt_npv'] for r in results]
    
    plt.figure(figsize=(10, 6))
    plt.hist(npvs, bins=50, density=True, alpha=0.7)
    plt.title('NPV Distribution')
    plt.xlabel('NPV ($)')
    plt.ylabel('Density')
    plt.axvline(x=np.mean(npvs), color='r', linestyle='--', label='Mean NPV')
    plt.legend()
    plt.show()

def plot_cumulative_cash_flow(results, sample_size=100):
    sampled_results = results if len(results) <= sample_size else np.random.choice(results, sample_size, replace=False)
    cash_flows = pd.DataFrame([generate_cash_flow(r) for r in sampled_results])
    cumulative_cash_flows = cash_flows.cumsum()
    
    mean_cumulative = cumulative_cash_flows.mean()
    std_cumulative = cumulative_cash_flows.std()
    
    years = range(len(mean_cumulative))
    plt.figure(figsize=(12, 6))
    plt.plot(years, mean_cumulative, label='Mean Cumulative Cash Flow')
    plt.fill_between(years, mean_cumulative - std_cumulative, mean_cumulative + std_cumulative, alpha=0.2)
    plt.title('Cumulative Cash Flow')
    plt.xlabel('Years')
    plt.ylabel('Cumulative Cash Flow ($)')
    plt.axhline(y=0, color='r', linestyle='--')
    plt.legend()
    plt.show()

def plot_phase_breakdown(results):
    phases = ['Præklinisk', 'Fase 1', 'Fase 2', 'Fase 3', 'Godkendelse']
    durations = [np.mean([r['præklinisk_tid'] for r in results]),
                 np.mean([r['fase1_tid'] for r in results]),
                 np.mean([r['fase2_tid'] for r in results]),
                 np.mean([r['fase3_tid'] for r in results]),
                 np.mean([r['godkendelse_tid'] for r in results])]
    
    costs = [np.mean([r['præklinisk_omkostninger'] for r in results]),
             np.mean([r['fase1_omkostninger'] for r in results]),
             np.mean([r['fase2_omkostninger'] for r in results]),
             np.mean([r['fase3_omkostninger'] for r in results]),
             np.mean([r['godkendelse_omkostninger'] for r in results])]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    ax1.bar(phases, durations)
    ax1.set_title('Average Phase Duration')
    ax1.set_ylabel('Years')
    ax1.set_xlabel('Development Phase')
    ax1.tick_params(axis='x', rotation=45)
    
    ax2.bar(phases, costs)
    ax2.set_title('Average Phase Cost')
    ax2.set_ylabel('Cost ($)')
    ax2.set_xlabel('Development Phase')
    ax2.tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()

# Assuming 'resultater' contains your simulation results
plot_cash_flow_projections(resultater)
plot_npv_distribution(resultater)
plot_cumulative_cash_flow(resultater)
plot_phase_breakdown(resultater)
